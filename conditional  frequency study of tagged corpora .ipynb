# %%
import nltk
from nltk.corpus import inaugural

corpus = inaugural.words()

cfd = nltk.ConditionalFreqDist((target, fileid[:4]) for fileid in inaugural.fileids() for target in inaugural.words(fileid))

print(cfd['freedom'].most_common())

cfd.plot(conditions=['freedom', 'liberty'])
# Out:
# [('2005', 25), ('1949', 13), ('1985', 12), ('1957', 11), ('1953', 9), ('1981', 7), ('1841', 6), ('1881', 6), ('1925', 6), ('1941', 6), ('2013', 6), ('1825', 5), ('1921', 5), ('1929', 5), ('2001', 5), ('1801', 4), ('1901', 4), ('1961', 4), ('1973', 4), ('1977', 4), ('1989', 4), ('1853', 3), ('1993', 3), ('2009', 3), ('1805', 2), ('1845', 2), ('1889', 2), ('1909', 2), ('1917', 2), ('1965', 2), ('1969', 2), ('1997', 2), ('1809', 1), ('1829', 1), ('1897', 1), ('1945', 1)]
# <Axes: xlabel='Samples', ylabel='Counts'>
